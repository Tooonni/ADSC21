# %% [markdown]
# # Imports

# %%
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Globale Variablen

# %%
ROOT_DIR = Path(os.getcwd()).parent
DATA_DIR = os.path.join(ROOT_DIR, "data")
DATA_DIR
important_data = []
num_data = 0

# %%
os.listdir(DATA_DIR)
# Out:
# ['game_lineups.csv',
#  'competitions.csv',
#  'appearances.csv',
#  'player_valuations.csv',
#  'game_events.csv',
#  'transfers.csv',
#  'players.csv',
#  'games.csv',
#  'club_games.csv',
#  'clubs.csv']

# %% [markdown]
# # game_lineups

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[0])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# game_lineups.csv
#                     game_lineups_id        date  game_id  player_id  club_id  \
# 0  b2dbe01c3656b06c8e23e9de714e26bb  2013-07-27  2317258       1443      610
# 1  b50a3ec6d52fd1490aab42042ac4f738  2013-07-27  2317258       5017      610
# 2  7d890e6d0ff8af84b065839966a0ec81  2013-07-27  2317258       9602     1090
# 3  8c355268678b9bbc7084221b1f0fde36  2013-07-27  2317258      12282      610
# 4  76193074d549e5fdce4cdcbba0d66247  2013-07-27  2317258      25427     1090
#
#          player_name             type            position number  team_captain
# 0  Christian Poulsen      substitutes  Defensive Midfield      5             0
# 1   Niklas Moisander  starting_lineup         Centre-Back      4             0
# 2    Maarten Martens      substitutes         Left Winger     11             0
# 3        Daley Blind  starting_lineup           Left-Back     17             0
# 4        Roy Beerens  starting_lineup        Right Winger     23             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191911 entries, 0 to 2191910
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   game_lineups_id  object
#  1   date             object
#  2   game_id          int64
#  3   player_id        int64
#  4   club_id          int64
#  5   player_name      object
#  6   type             object
#  7   position         object
#  8   number           object
#  9   team_captain     int64
# dtypes: int64(4), object(6)
# memory usage: 167.2+ MB

# %% [markdown]
# Beinhaltet: Welche Spieler zum welchen Spiel gespielt haben
# - könnte wichtig sein, weil dadurch ermittelt wird wie viele male ein Spieler gespielt hat und welche Rolle er meistens hat (Einwechslen- vs. Startelfspieler)

# %%
important_data.append(os.listdir(DATA_DIR)[num_data])
num_data += 1

# %% [markdown]
# # competitions (nicht notwendig)

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# competitions.csv
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# 3         136     Portugal                  PO1        europa
# 4         141       Russia                  RU1        europa
#
#                                                  url  is_major_national_league
# 0  https://www.transfermarkt.co.uk/italy-cup/star...                     False
# 1  https://www.transfermarkt.co.uk/johan-cruijff-...                     False
# 2  https://www.transfermarkt.co.uk/kypello-ellada...                     False
# 3  https://www.transfermarkt.co.uk/supertaca-cand...                     False
# 4  https://www.transfermarkt.co.uk/russian-super-...                     False

# %% [markdown]
# Beinhaltet: alle Wettbewerbe im Fußball
# - eher unwichtig für den Marktwert

# %%
num_data += 1

# %% [markdown]
# # appearances

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# appearances.csv
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# 0      2        0              90
# 1      0        0              90
# 2      0        0              45
# 3      0        0              90
# 4      0        1              90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1706806 entries, 0 to 1706805
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   appearance_id           object
#  1   game_id                 int64
#  2   player_id               int64
#  3   player_club_id          int64
#  4   player_current_club_id  int64
#  5   date                    object
#  6   player_name             object
#  7   competition_id          object
#  8   yellow_cards            int64
#  9   red_cards               int64
#  10  goals                   int64
#  11  assists                 int64
#  12  minutes_played          int64
# dtypes: int64(9), object(4)
# memory usage: 169.3+ MB

# %% [markdown]
# Beinhaltet: für jeden Spieler genaue Details zum jeden Spiel (Gelbe/Rote Karten, Tore, Vorlagen, gespielte Minuten)
# - könnte wichtig sein um die weitere Statistiken für ein Spiele zu messen

# %%
important_data.append(os.listdir(DATA_DIR)[num_data])
num_data += 1

# %% [markdown]
# # player_valuations

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# player_valuations.csv
#    player_id        date  market_value_in_eur  current_club_id  \
# 0     405973  2000-01-20               150000             3057
# 1     342216  2001-07-20               100000             1241
# 2       3132  2003-12-09               400000              126
# 3       6893  2003-12-15               900000              984
# 4         10  2004-10-04              7000000              398
#
#   player_club_domestic_competition_id
# 0                                 BE1
# 1                                 SC1
# 2                                 TR1
# 3                                 GB1
# 4                                 IT1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496606 entries, 0 to 496605
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   player_id                            496606 non-null  int64
#  1   date                                 496606 non-null  object
#  2   market_value_in_eur                  496606 non-null  int64
#  3   current_club_id                      496606 non-null  int64
#  4   player_club_domestic_competition_id  496606 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 18.9+ MB

# %% [markdown]
# Beinhaltet: für jeden Spieler zu welchen Datum er welchen Marktwert, welchen Club und welche Liga er gespielt hat
# - könnte wichtig sein um den Zeitverlauf und welche Liga vllt tendenziell teurere Spieler hat

# %%
important_data.append(os.listdir(DATA_DIR)[num_data])
num_data += 1

# %% [markdown]
# # game_events (nicht notwendig)

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# game_events.csv
#                       game_event_id        date  game_id  minute  \
# 0  2f41da30c471492e7d4a984951671677  2012-08-05  2211607      77
# 1  a72f7186d132775f234d3e2f7bc0ed5b  2012-08-05  2211607      77
# 2  b2d721eaed4692a5c59a92323689ef18  2012-08-05  2211607       3
# 3  aef768899cedac0c9a650980219075a2  2012-08-05  2211607      53
# 4  5d6d9533023057b6619ecd145a038bbe  2012-08-05  2211607      74
#
#             type  club_id  player_id  \
# 0          Cards      610       4425
# 1          Cards      383      33210
# 2          Goals      383      36500
# 3          Goals      383      36500
# 4  Substitutions      383      36500
#
#                                          description  player_in_id  \
# 0               1. Yellow card  , Mass confrontation           NaN
# 1               1. Yellow card  , Mass confrontation           NaN
# 2  , Header, 1. Tournament Goal Assist: , Corner,...           NaN
# 3  , Right-footed shot, 2. Tournament Goal Assist...           NaN
# 4                                     , Not reported       49499.0
#
#    player_assist_id
# 0               NaN
# 1               NaN
# 2           56416.0
# 3          146258.0
# 4               NaN

# %% [markdown]
# Beinhaltet: zu den jeweiligen Spiele, wann zu welchen Zeit was und vom wem passiert ist
# - sehr detailiert und wird bereits zusammengefasst in appearances; daher erstmal nicht wichtig

# %%
num_data += 1

# %% [markdown]
# # transfers

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# transfers.csv
#    player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0      16136    2026-07-01           26/27           417         123
# 1    1138758    2026-07-01           26/27           336         631
# 2     195778    2026-06-30           25/26            79          27
# 3     569033    2026-06-30           25/26            39          27
# 4     626913    2026-06-30           25/26           398         380
#
#    from_club_name   to_club_name  transfer_fee  market_value_in_eur  \
# 0        OGC Nice        Retired           NaN             500000.0
# 1     Sporting CP        Chelsea    52140000.0           45000000.0
# 2   VfB Stuttgart  Bayern Munich           0.0           12000000.0
# 3  1.FSV Mainz 05  Bayern Munich           0.0            4000000.0
# 4           Lazio    Salernitana           0.0           15000000.0
#
#        player_name
# 0            Dante
# 1   Geovany Quenda
# 2  Alexander Nübel
# 3     Armindo Sieb
# 4      Boulaye Dia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79646 entries, 0 to 79645
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_id            79646 non-null  int64
#  1   transfer_date        79646 non-null  object
#  2   transfer_season      79646 non-null  object
#  3   from_club_id         79646 non-null  int64
#  4   to_club_id           79646 non-null  int64
#  5   from_club_name       79646 non-null  object
#  6   to_club_name         79646 non-null  object
#  7   transfer_fee         51931 non-null  float64
#  8   market_value_in_eur  49330 non-null  float64
#  9   player_name          79646 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.1+ MB

# %% [markdown]
# Beinhaltet: Transferdaten - Wann, von wo zu wo, Transfersumme und Marktwert

# %%
important_data.append(os.listdir(DATA_DIR)[num_data])
num_data += 1

# %% [markdown]
# # players

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# players.csv
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# 0                Germany  ...  right        184.0                      NaN
# 1                Germany  ...   left        190.0                      NaN
# 2               Bulgaria  ...    NaN          NaN                      NaN
# 3                 Brazil  ...    NaN          NaN                      NaN
# 4                Germany  ...  right        194.0                      NaN
#
#              agent_name                                          image_url  \
# 0  ASBW Sport Marketing  https://img.a.transfermarkt.technology/portrai...
# 1      Neubauer 13 GmbH  https://img.a.transfermarkt.technology/portrai...
# 2       CSKA-AS-23 Ltd.  https://img.a.transfermarkt.technology/portrai...
# 3                   NaN  https://img.a.transfermarkt.technology/portrai...
# 4                   IFM  https://img.a.transfermarkt.technology/portrai...
#
#                                                  url  \
# 0  https://www.transfermarkt.co.uk/miroslav-klose...
# 1  https://www.transfermarkt.co.uk/roman-weidenfe...
# 2  https://www.transfermarkt.co.uk/dimitar-berbat...
# 3  https://www.transfermarkt.co.uk/lucio/profil/s...
# 4  https://www.transfermarkt.co.uk/tom-starke/pro...
#
#   current_club_domestic_competition_id  \
# 0                                  IT1
# 1                                   L1
# 2                                  GR1
# 3                                  IT1
# 4                                   L1
#
#                                    current_club_name market_value_in_eur  \
# 0                      Società Sportiva Lazio S.p.A.           1000000.0
# 1                                  Borussia Dortmund            750000.0
# 2  Panthessalonikios Athlitikos Omilos Konstantin...           1000000.0
# 3                             Juventus Football Club            200000.0
# 4                                  FC Bayern München            100000.0
#
#   highest_market_value_in_eur
# 0                  30000000.0
# 1                   8000000.0
# 2                  34500000.0
# 3                  24500000.0
# 4                   3000000.0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32601 entries, 0 to 32600
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             32601 non-null  int64
#  1   first_name                            30539 non-null  object
#  2   last_name                             32601 non-null  object
#  3   name                                  32601 non-null  object
#  4   last_season                           32601 non-null  int64
#  5   current_club_id                       32601 non-null  int64
#  6   player_code                           32601 non-null  object
#  7   country_of_birth                      29802 non-null  object
#  8   city_of_birth                         30146 non-null  object
#  9   country_of_citizenship                32218 non-null  object
#  10  date_of_birth                         32554 non-null  object
#  11  sub_position                          32421 non-null  object
#  12  position                              32601 non-null  object
#  13  foot                                  30065 non-null  object
#  14  height_in_cm                          30345 non-null  float64
#  15  contract_expiration_date              20510 non-null  object
#  16  agent_name                            16582 non-null  object
#  17  image_url                             32601 non-null  object
#  18  url                                   32601 non-null  object
#  19  current_club_domestic_competition_id  32601 non-null  object
#  20  current_club_name                     32601 non-null  object
#  21  market_value_in_eur                   31078 non-null  float64
#  22  highest_market_value_in_eur           31078 non-null  float64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 5.7+ MB

# %%
df["last_season"].value_counts().plot(kind="bar")
plt.xlabel("Summe der letzten Saisons")
plt.ylabel("Anzahl der Spieler")
plt.title("Anzahl der Spieler pro letzter Saison")
plt.show()

# %%
df[(df["last_season"] == 2024) & (df["market_value_in_eur"] > 50000000)].sort_values(by="market_value_in_eur", ascending=False)
# Out:
#        player_id first_name        last_name             name  last_season  \
# 21637     418560     Erling          Haaland   Erling Haaland         2024
# 19985     371998        NaN  Vinicius Junior  Vinicius Junior         2024
# 25766     581678       Jude       Bellingham  Jude Bellingham         2024
# 31174     937958        NaN     Lamine Yamal     Lamine Yamal         2024
# 18778     342229     Kylian           Mbappé    Kylian Mbappé         2024
# ...          ...        ...              ...              ...          ...
# 23432     485706     Amadou            Onana     Amadou Onana         2024
# 10055     148455        NaN    Mohamed Salah    Mohamed Salah         2024
# 19448     355915   Cristian           Romero  Cristian Romero         2024
# 14349     240306      Bruno        Fernandes  Bruno Fernandes         2024
# 31667    1005649        NaN          Murillo          Murillo         2024
#
#        current_club_id      player_code country_of_birth  \
# 21637              281   erling-haaland          England
# 19985              418  vinicius-junior           Brazil
# 25766              418  jude-bellingham          England
# 31174              131     lamine-yamal            Spain
# 18778              418    kylian-mbappe           France
# ...                ...              ...              ...
# 23432              405     amadou-onana          Senegal
# 10055               31    mohamed-salah            Egypt
# 19448              148  cristian-romero        Argentina
# 14349              985  bruno-fernandes         Portugal
# 31667              703          murillo           Brazil
#
#                 city_of_birth country_of_citizenship  ...   foot height_in_cm  \
# 21637                   Leeds                 Norway  ...   left        195.0
# 19985             São Gonçalo                 Brazil  ...  right        176.0
# 25766             Stourbridge                England  ...  right        186.0
# 31174  Esplugues de Llobregat                  Spain  ...   left        180.0
# 18778                   Paris                 France  ...  right        178.0
# ...                       ...                    ...  ...    ...          ...
# 23432                   Dakar                Belgium  ...  right        195.0
# 10055         Nagrig, Basyoun                  Egypt  ...   left        175.0
# 19448                 Córdoba              Argentina  ...  right        185.0
# 14349                    Maia               Portugal  ...  right        179.0
# 31667               São Paulo                 Brazil  ...   left        180.0
#
#       contract_expiration_date         agent_name  \
# 21637      2034-06-30 00:00:00    Rafaela Pimenta
# 19985      2027-06-30 00:00:00  Roc Nation Sports
# 25766      2029-06-30 00:00:00                NaN
# 31174      2026-06-30 00:00:00                NaN
# 18778      2029-06-30 00:00:00                NaN
# ...                        ...                ...
# 23432      2029-06-30 00:00:00               BTFM
# 10055      2025-06-30 00:00:00                NaN
# 19448      2027-06-30 00:00:00       Ciro Palermo
# 14349      2027-06-30 00:00:00                AS1
# 31667      2029-06-30 00:00:00           FWD Team
#
#                                                image_url  \
# 21637  https://img.a.transfermarkt.technology/portrai...
# 19985  https://img.a.transfermarkt.technology/portrai...
# 25766  https://img.a.transfermarkt.technology/portrai...
# 31174  https://img.a.transfermarkt.technology/portrai...
# 18778  https://img.a.transfermarkt.technology/portrai...
# ...                                                  ...
# 23432  https://img.a.transfermarkt.technology/portrai...
# 10055  https://img.a.transfermarkt.technology/portrai...
# 19448  https://img.a.transfermarkt.technology/portrai...
# 14349  https://img.a.transfermarkt.technology/portrai...
# 31667  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 21637  https://www.transfermarkt.co.uk/erling-haaland...
# 19985  https://www.transfermarkt.co.uk/vinicius-junio...
# 25766  https://www.transfermarkt.co.uk/jude-bellingha...
# 31174  https://www.transfermarkt.co.uk/lamine-yamal/p...
# 18778  https://www.transfermarkt.co.uk/kylian-mbappe/...
# ...                                                  ...
# 23432  https://www.transfermarkt.co.uk/amadou-onana/p...
# 10055  https://www.transfermarkt.co.uk/mohamed-salah/...
# 19448  https://www.transfermarkt.co.uk/cristian-romer...
# 14349  https://www.transfermarkt.co.uk/bruno-fernande...
# 31667  https://www.transfermarkt.co.uk/murillo/profil...
#
#       current_club_domestic_competition_id                current_club_name  \
# 21637                                  GB1    Manchester City Football Club
# 19985                                  ES1       Real Madrid Club de Fútbol
# 25766                                  ES1       Real Madrid Club de Fútbol
# 31174                                  ES1            Futbol Club Barcelona
# 18778                                  ES1       Real Madrid Club de Fútbol
# ...                                    ...                              ...
# 23432                                  GB1        Aston Villa Football Club
# 10055                                  GB1          Liverpool Football Club
# 19448                                  GB1  Tottenham Hotspur Football Club
# 14349                                  GB1  Manchester United Football Club
# 31667                                  GB1  Nottingham Forest Football Club
#
#       market_value_in_eur highest_market_value_in_eur
# 21637         200000000.0                 200000000.0
# 19985         200000000.0                 200000000.0
# 25766         180000000.0                 180000000.0
# 31174         180000000.0                 180000000.0
# 18778         170000000.0                 200000000.0
# ...                   ...                         ...
# 23432          55000000.0                  55000000.0
# 10055          55000000.0                 150000000.0
# 19448          55000000.0                  65000000.0
# 14349          55000000.0                  90000000.0
# 31667          55000000.0                  55000000.0
#
# [87 rows x 23 columns]

# %%
df[df["last_season"] == 2022].sort_values(by="market_value_in_eur", ascending=False)
# Out:
#        player_id first_name         last_name                     name  \
# 5941       68290        NaN            Neymar                   Neymar
# 15585     266302     Sergej  Milinković-Savić  Sergej Milinković-Savić
# 13631     225161      Rúben             Neves              Rúben Neves
# 13656     225693        NaN           Fabinho                  Fabinho
# 2347       28003     Lionel             Messi             Lionel Messi
# ...          ...        ...               ...                      ...
# 32325    1143805  Oleksandr         Tsvirenko      Oleksandr Tsvirenko
# 32328    1143808      Pavlo             Ripak              Pavlo Ripak
# 32330    1143810      Roman        Yuvkhymets         Roman Yuvkhymets
# 32331    1143811   Yaroslav           Shandra         Yaroslav Shandra
# 32333    1143823      Denys        Dovbetskyi         Denys Dovbetskyi
#
#        last_season  current_club_id              player_code country_of_birth  \
# 5941          2022              583                   neymar           Brazil
# 15585         2022              398  sergej-milinković-savić              NaN
# 13631         2022              543              ruben-neves         Portugal
# 13656         2022               31                  fabinho           Brazil
# 2347          2022              583             lionel-messi        Argentina
# ...            ...              ...                      ...              ...
# 32325         2022            83678      oleksandr-tsvirenko              NaN
# 32328         2022            18105              pavlo-ripak              NaN
# 32330         2022            18105         roman-yuvkhymets          Ukraine
# 32331         2022            18105         yaroslav-shandra          Ukraine
# 32333         2022            18105         denys-dovbetskyi              NaN
#
#                                city_of_birth country_of_citizenship  ...  \
# 5941                         Mogi das Cruzes                 Brazil  ...
# 15585                                 Lleida                    NaN  ...
# 13631                   Santa Maria da Feira               Portugal  ...
# 13656                               Campinas                 Brazil  ...
# 2347                                 Rosario              Argentina  ...
# ...                                      ...                    ...  ...
# 32325                                    NaN                Ukraine  ...
# 32328                                    NaN                Ukraine  ...
# 32330  Velykyi Pravutyn, Khmelnytskyi Oblast                Ukraine  ...
# 32331                Rava-Ruska, Lviv Oblast                Ukraine  ...
# 32333                                    NaN                Ukraine  ...
#
#         foot height_in_cm contract_expiration_date     agent_name  \
# 5941   right        175.0      2025-06-30 00:00:00            NaN
# 15585  right        191.0      2024-06-30 00:00:00  Mateja Kezman
# 13631  right        180.0      2026-06-30 00:00:00      Gestifute
# 13656  right        188.0      2026-06-30 00:00:00      Gestifute
# 2347    left        170.0                      NaN            NaN
# ...      ...          ...                      ...            ...
# 32325  right        185.0                      NaN            NaN
# 32328    NaN        184.0                      NaN            NaN
# 32330  right        179.0                      NaN            NaN
# 32331  right        181.0                      NaN            NaN
# 32333  right        173.0                      NaN            NaN
#
#                                                image_url  \
# 5941   https://img.a.transfermarkt.technology/portrai...
# 15585  https://img.a.transfermarkt.technology/portrai...
# 13631  https://img.a.transfermarkt.technology/portrai...
# 13656  https://img.a.transfermarkt.technology/portrai...
# 2347   https://img.a.transfermarkt.technology/portrai...
# ...                                                  ...
# 32325  https://img.a.transfermarkt.technology/portrai...
# 32328  https://img.a.transfermarkt.technology/portrai...
# 32330  https://img.a.transfermarkt.technology/portrai...
# 32331  https://img.a.transfermarkt.technology/portrai...
# 32333  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 5941   https://www.transfermarkt.co.uk/neymar/profil/...
# 15585  https://www.transfermarkt.co.uk/sergej-milinko...
# 13631  https://www.transfermarkt.co.uk/ruben-neves/pr...
# 13656  https://www.transfermarkt.co.uk/fabinho/profil...
# 2347   https://www.transfermarkt.co.uk/lionel-messi/p...
# ...                                                  ...
# 32325  https://www.transfermarkt.co.uk/oleksandr-tsvi...
# 32328  https://www.transfermarkt.co.uk/pavlo-ripak/pr...
# 32330  https://www.transfermarkt.co.uk/roman-yuvkhyme...
# 32331  https://www.transfermarkt.co.uk/yaroslav-shand...
# 32333  https://www.transfermarkt.co.uk/denys-dovbetsk...
#
#       current_club_domestic_competition_id  \
# 5941                                   FR1
# 15585                                  IT1
# 13631                                  GB1
# 13656                                  GB1
# 2347                                   FR1
# ...                                    ...
# 32325                                 UKR1
# 32328                                 UKR1
# 32330                                 UKR1
# 32331                                 UKR1
# 32333                                 UKR1
#
#                            current_club_name market_value_in_eur  \
# 5941       Paris Saint-Germain Football Club          50000000.0
# 15585          Società Sportiva Lazio S.p.A.          40000000.0
# 13631  Wolverhampton Wanderers Football Club          40000000.0
# 13656                Liverpool Football Club          38000000.0
# 2347       Paris Saint-Germain Football Club          35000000.0
# ...                                      ...                 ...
# 32325                       Metalist Kharkiv                 NaN
# 32328                               PFK Lviv                 NaN
# 32330                               PFK Lviv                 NaN
# 32331                               PFK Lviv                 NaN
# 32333                               PFK Lviv                 NaN
#
#       highest_market_value_in_eur
# 5941                  180000000.0
# 15585                  90000000.0
# 13631                  50000000.0
# 13656                  70000000.0
# 2347                  180000000.0
# ...                           ...
# 32325                         NaN
# 32328                         NaN
# 32330                         NaN
# 32331                         NaN
# 32333                         NaN
#
# [2643 rows x 23 columns]

# %% [markdown]
# Beinhaltet: persönliche Daten, Position, Fußstärke, Ablaufdatum des Vertrages, Agenten, Welcher Club, Marktwert und höchster Marktwert

# %%
important_data.append(os.listdir(DATA_DIR)[num_data])
num_data += 1

# %% [markdown]
# # games (nicht notwendig)

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# games.csv
#    game_id competition_id  season        round        date  home_club_id  \
# 0  2321027             L1    2013  1. Matchday  2013-08-11          33.0
# 1  2321033             L1    2013  1. Matchday  2013-08-10          23.0
# 2  2321044             L1    2013  2. Matchday  2013-08-18          16.0
# 3  2321060             L1    2013  3. Matchday  2013-08-25          23.0
# 4  2321072             L1    2013  5. Matchday  2013-09-14          16.0
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0          41.0              3.0              3.0                 8.0  ...
# 1          86.0              0.0              1.0                13.0  ...
# 2          23.0              2.0              1.0                 1.0  ...
# 3          24.0              0.0              2.0                18.0  ...
# 4          41.0              6.0              2.0                 1.0  ...
#
#              stadium attendance         referee  \
# 0      Veltins-Arena    61973.0    Manuel Gräfe
# 1  EINTRACHT-Stadion    23000.0   Deniz Aytekin
# 2  SIGNAL IDUNA PARK    80200.0    Peter Sippel
# 3  EINTRACHT-Stadion    23325.0  Wolfgang Stark
# 4  SIGNAL IDUNA PARK    80645.0     Tobias Welz
#
#                                                  url  home_club_formation  \
# 0  https://www.transfermarkt.co.uk/fc-schalke-04_...              4-2-3-1
# 1  https://www.transfermarkt.co.uk/eintracht-brau...              4-3-2-1
# 2  https://www.transfermarkt.co.uk/borussia-dortm...              4-2-3-1
# 3  https://www.transfermarkt.co.uk/eintracht-brau...              4-3-2-1
# 4  https://www.transfermarkt.co.uk/borussia-dortm...              4-2-3-1
#
#   away_club_formation          home_club_name  \
# 0             4-2-3-1           FC Schalke 04
# 1             4-3-1-2  Eintracht Braunschweig
# 2             4-3-2-1       Borussia Dortmund
# 3             4-2-3-1  Eintracht Braunschweig
# 4               3-5-2       Borussia Dortmund
#
#                        away_club_name aggregate competition_type
# 0                        Hamburger SV       3:3  domestic_league
# 1  Sportverein Werder Bremen von 1899       0:1  domestic_league
# 2              Eintracht Braunschweig       2:1  domestic_league
# 3      Eintracht Frankfurt Fußball AG       0:2  domestic_league
# 4                        Hamburger SV       6:2  domestic_league
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74026 entries, 0 to 74025
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 74026 non-null  int64
#  1   competition_id          74026 non-null  object
#  2   season                  74026 non-null  int64
#  3   round                   74026 non-null  object
#  4   date                    74026 non-null  object
#  5   home_club_id            74017 non-null  float64
#  6   away_club_id            74017 non-null  float64
#  7   home_club_goals         74014 non-null  float64
#  8   away_club_goals         74014 non-null  float64
#  9   home_club_position      51559 non-null  float64
#  10  away_club_position      51559 non-null  float64
#  11  home_club_manager_name  73198 non-null  object
#  12  away_club_manager_name  73198 non-null  object
#  13  stadium                 73776 non-null  object
#  14  attendance              64078 non-null  float64
#  15  referee                 73374 non-null  object
#  16  url                     74026 non-null  object
#  17  home_club_formation     67051 non-null  object
#  18  away_club_formation     67220 non-null  object
#  19  home_club_name          61176 non-null  object
#  20  away_club_name          62571 non-null  object
#  21  aggregate               74014 non-null  object
#  22  competition_type        74026 non-null  object
# dtypes: float64(7), int64(2), object(14)
# memory usage: 13.0+ MB

# %% [markdown]
# Beinhaltet: oberflächige Infos für ein Spiel
# - eher nicht relevant

# %% [markdown]
# # club_games (nicht notwendig)

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# games.csv
#    game_id competition_id  season        round        date  home_club_id  \
# 0  2321027             L1    2013  1. Matchday  2013-08-11          33.0
# 1  2321033             L1    2013  1. Matchday  2013-08-10          23.0
# 2  2321044             L1    2013  2. Matchday  2013-08-18          16.0
# 3  2321060             L1    2013  3. Matchday  2013-08-25          23.0
# 4  2321072             L1    2013  5. Matchday  2013-09-14          16.0
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0          41.0              3.0              3.0                 8.0  ...
# 1          86.0              0.0              1.0                13.0  ...
# 2          23.0              2.0              1.0                 1.0  ...
# 3          24.0              0.0              2.0                18.0  ...
# 4          41.0              6.0              2.0                 1.0  ...
#
#              stadium attendance         referee  \
# 0      Veltins-Arena    61973.0    Manuel Gräfe
# 1  EINTRACHT-Stadion    23000.0   Deniz Aytekin
# 2  SIGNAL IDUNA PARK    80200.0    Peter Sippel
# 3  EINTRACHT-Stadion    23325.0  Wolfgang Stark
# 4  SIGNAL IDUNA PARK    80645.0     Tobias Welz
#
#                                                  url  home_club_formation  \
# 0  https://www.transfermarkt.co.uk/fc-schalke-04_...              4-2-3-1
# 1  https://www.transfermarkt.co.uk/eintracht-brau...              4-3-2-1
# 2  https://www.transfermarkt.co.uk/borussia-dortm...              4-2-3-1
# 3  https://www.transfermarkt.co.uk/eintracht-brau...              4-3-2-1
# 4  https://www.transfermarkt.co.uk/borussia-dortm...              4-2-3-1
#
#   away_club_formation          home_club_name  \
# 0             4-2-3-1           FC Schalke 04
# 1             4-3-1-2  Eintracht Braunschweig
# 2             4-3-2-1       Borussia Dortmund
# 3             4-2-3-1  Eintracht Braunschweig
# 4               3-5-2       Borussia Dortmund
#
#                        away_club_name aggregate competition_type
# 0                        Hamburger SV       3:3  domestic_league
# 1  Sportverein Werder Bremen von 1899       0:1  domestic_league
# 2              Eintracht Braunschweig       2:1  domestic_league
# 3      Eintracht Frankfurt Fußball AG       0:2  domestic_league
# 4                        Hamburger SV       6:2  domestic_league
#
# [5 rows x 23 columns]

# %% [markdown]
# Beinhaltet: für jedes Spiel ein paar Infos
# - nicht relevant

# %%
num_data += 1

# %% [markdown]
# # clubs (nicht notwendig)

# %%
df = pd.read_csv(DATA_DIR + "/" + os.listdir(DATA_DIR)[num_data])
print(os.listdir(DATA_DIR)[num_data])
df.head()
# Out:
# club_games.csv
#    game_id  club_id  own_goals  own_position   own_manager_name  opponent_id  \
# 0  2320450   1468.0        0.0           NaN  Holger Bachthaler         24.0
# 1  2320454    222.0        0.0           NaN        Volkan Uluc         79.0
# 2  2320460      1.0        3.0           NaN    Jürgen Luginger         86.0
# 3  2320472   2036.0        4.0           NaN      Frank Schmidt         72.0
# 4  2321027     33.0        3.0           8.0        Jens Keller         41.0
#
#    opponent_goals  opponent_position opponent_manager_name hosting  is_win
# 0             2.0                NaN             Armin Veh    Home       0
# 1             2.0                NaN        Bruno Labbadia    Home       0
# 2             1.0                NaN            Robin Dutt    Home       1
# 3             5.0                NaN     Alexander Schmidt    Home       0
# 4             3.0                9.0         Thorsten Fink    Home       0

# %% [markdown]
# Beinhaltet: für jede Mannschaft zusätzliche Info; Mannschaftsgröße, Alter etc.
# - kann eventuell nutzbar sein

# %%
num_data += 1

# %% [markdown]
# # Auswertung
#
# Hier sind alle wichtige Daten, die nun zusammengebracht werden müssen

# %%
important_data
# Out:
# ['game_lineups.csv',
#  'appearances.csv',
#  'player_valuations.csv',
#  'transfers.csv',
#  'players.csv']

# %% [markdown]
# ## Merge wichtige CSVs zu einem Dataset
#
# Bauen einer Trainings-Tabelle mit Zielvariable `market_value_in_eur` aus `player_valuations.csv` und reichern sie an mit:
# - Stammdaten aus `players.csv` (z. B. Position, Geburtsdatum → Alter)
# - Club-Infos aus `clubs.csv` (z. B. Clubname, Liga)
# - Einfachen aggregierten Leistungsmerkmalen aus `appearances.csv` (z. B. Gesamtminuten, Tore)
# - Optional: `game_lineups.csv` als einfache Zähl-Feature (wie oft im Lineup)
